# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('CleanedDf.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                      CompanyName       Location  \
# 0           0               NXP Semiconductors     Austin, TX
# 1           2     Matrix New World Engineering         Remote
# 2           3                     Context Labs  Cambridge, MA
# 3           5                 Ryden Global LLC         Remote
# 4           8  Buchanan And Edwards Group\n4.0     McLean, VA
#
#                                            Job_Title  \
# 0  Entry Level Data Science - December 2023 and M...
# 1                                     Data Scientist
# 2                                     Data Scientist
# 3                                     Data Scientist
# 4                                     Data Scientist
#
#                                       SalaryEstimate  \
# 0  NXP Semiconductors4.1 ★\nEntry Level Data Scie...
# 1  Matrix New World Engineering4 ★\nData Scientis...
# 2  Context Labs\nData Scientist\nCambridge, MA\nU...
# ...

# %%
df['CompanyName'] = df['CompanyName'].replace({'Buchanan And Edwards Group\n4.0':'Buchanan And Edwards Group'})

# %%
df.CompanyName.value_counts()
# Out:
# CompanyName
# Unknown                         209
# Nexlogica                        30
# Context Labs                     30
# Ryden Global LLC                 30
# Buchanan And Edwards Group       30
# Tech brothers infoservices       30
# MetroStar                        30
# Brainwave360                     30
# Matrix New World Engineering     30
# Lendistry                        30
# Sunixa Solutions                 30
# plaxonic                         30
# Publicis Media                   30
# Tidepool                         30
# FAST GROWING TREES LLC           30
# SilverEdge                       29
# NXP Semiconductors                1
# Name: count, dtype: int64

# %%
df.drop(columns=df.columns[0], axis=1, inplace=True)

# %%
df.head()
# Out:
#                     CompanyName       Location  \
# 0            NXP Semiconductors     Austin, TX
# 1  Matrix New World Engineering         Remote
# 2                  Context Labs  Cambridge, MA
# 3              Ryden Global LLC         Remote
# 4    Buchanan And Edwards Group     McLean, VA
#
#                                            Job_Title  \
# 0  Entry Level Data Science - December 2023 and M...
# 1                                     Data Scientist
# 2                                     Data Scientist
# 3                                     Data Scientist
# 4                                     Data Scientist
#
#                                       SalaryEstimate  \
# 0  NXP Semiconductors4.1 ★\nEntry Level Data Scie...
# 1  Matrix New World Engineering4 ★\nData Scientis...
# 2  Context Labs\nData Scientist\nCambridge, MA\nU...
# 3  Ryden Global LLC\nData Scientist\nRemote\nUS$6...
# 4  Buchanan And Edwards Group4 ★\nData Scientist\...
#
# ...

# %%
df.drop(['Aws', 'Sql', 'MachineLearning', 'sql', 'Spark'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                     CompanyName       Location  \
# 0            NXP Semiconductors     Austin, TX
# 1  Matrix New World Engineering         Remote
# 2                  Context Labs  Cambridge, MA
# 3              Ryden Global LLC         Remote
# 4    Buchanan And Edwards Group     McLean, VA
#
#                                            Job_Title  \
# 0  Entry Level Data Science - December 2023 and M...
# 1                                     Data Scientist
# 2                                     Data Scientist
# 3                                     Data Scientist
# 4                                     Data Scientist
#
#                                       SalaryEstimate  \
# 0  NXP Semiconductors4.1 ★\nEntry Level Data Scie...
# 1  Matrix New World Engineering4 ★\nData Scientis...
# 2  Context Labs\nData Scientist\nCambridge, MA\nU...
# 3  Ryden Global LLC\nData Scientist\nRemote\nUS$6...
# 4  Buchanan And Edwards Group4 ★\nData Scientist\...
#
# ...

# %%
df.drop(['HourlymaxSal'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                     CompanyName       Location  \
# 0            NXP Semiconductors     Austin, TX
# 1  Matrix New World Engineering         Remote
# 2                  Context Labs  Cambridge, MA
# 3              Ryden Global LLC         Remote
# 4    Buchanan And Edwards Group     McLean, VA
#
#                                            Job_Title  \
# 0  Entry Level Data Science - December 2023 and M...
# 1                                     Data Scientist
# 2                                     Data Scientist
# 3                                     Data Scientist
# 4                                     Data Scientist
#
#                                       SalaryEstimate  \
# 0  NXP Semiconductors4.1 ★\nEntry Level Data Scie...
# 1  Matrix New World Engineering4 ★\nData Scientis...
# 2  Context Labs\nData Scientist\nCambridge, MA\nU...
# 3  Ryden Global LLC\nData Scientist\nRemote\nUS$6...
# 4  Buchanan And Edwards Group4 ★\nData Scientist\...
#
# ...

# %%
df.RevenueType.value_counts()
# Out:
# RevenueType
# -2                          238
# Unknown / Non-Applicable    180
# $25 to $50 million (USD)     90
# $1 to $5 million (USD)       90
# $5 to $10 billion (USD)      31
# $5 to $25 million (USD)      30
# Name: count, dtype: int64

# %%
df['RevenueType'] = df['RevenueType'].replace({'-2':'Unknown'})

# %%
df.RevenueType.value_counts()
# Out:
# RevenueType
# Unknown                     238
# Unknown / Non-Applicable    180
# $25 to $50 million (USD)     90
# $1 to $5 million (USD)       90
# $5 to $10 billion (USD)      31
# $5 to $25 million (USD)      30
# Name: count, dtype: int64

# %%
df.drop(['minSalary', 'maxSalary'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                     CompanyName       Location  \
# 0            NXP Semiconductors     Austin, TX
# 1  Matrix New World Engineering         Remote
# 2                  Context Labs  Cambridge, MA
# 3              Ryden Global LLC         Remote
# 4    Buchanan And Edwards Group     McLean, VA
#
#                                            Job_Title  \
# 0  Entry Level Data Science - December 2023 and M...
# 1                                     Data Scientist
# 2                                     Data Scientist
# 3                                     Data Scientist
# 4                                     Data Scientist
#
#                                       SalaryEstimate  \
# 0  NXP Semiconductors4.1 ★\nEntry Level Data Scie...
# 1  Matrix New World Engineering4 ★\nData Scientis...
# 2  Context Labs\nData Scientist\nCambridge, MA\nU...
# 3  Ryden Global LLC\nData Scientist\nRemote\nUS$6...
# 4  Buchanan And Edwards Group4 ★\nData Scientist\...
#
# ...
