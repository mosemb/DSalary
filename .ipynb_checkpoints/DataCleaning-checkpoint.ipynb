# %%
import pandas as pd

# %%
df = pd.read_csv('DataScienceDf.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0                        CompanyName       Location  \
# 0           0            NXP Semiconductors\n4.1     Austin, TX
# 1           1             State of Virginia\n3.6         Remote
# 2           2  Matrix New World Engineering\n4.0         Remote
# 3           3                       Context Labs  Cambridge, MA
# 4           4                            Unknown  Cambridge, MA
#
#                                            Job_Title  \
# 0  Entry Level Data Science - December 2023 and M...
# 1                                     Data Scientist
# 2                                     Data Scientist
# 3                                     Data Scientist
# 4                                     Data Scientist
#
#                                       SalaryEstimate  \
# 0  NXP Semiconductors4.1 ★\nEntry Level Data Scie...
# 1  State of Virginia3.6 ★\nData Scientist\nRemote...
# 2  Matrix New World Engineering4 ★\nData Scientis...
# 3  Context Labs\nData Scientist\nCambridge, MA\nU...
# 4  CORMAC3.8 ★\nJr. Data Scientist\nRemote\nEasy ...
#
#                                             Job_Desc    NumberOfEmployees  \
# 0  Our business runs on Data, and having an accur...     10000+ Employees
# 1  Job Duties/Responsibilities may include, but a...     10000+ Employees
# 2  Are you passionate about finding insights from...  51 to 200 Employees
# 3  Context Labs is seeking a Data Scientist to su...              Unknown
# 4  Context Labs is seeking a Data Scientist to su...              Unknown
#
#        FoundingYear           CompanyType  \
# 0              2006      Company - Public
# 1              1788            Government
# 2              1990     Company - Private
# 3  Company - Public  Software Development
# 4  Company - Public  Software Development
#
#                            IndustryType  \
# 0             Electronics Manufacturing
# 1                     Regional Agencies
# 2  Architectural & Engineering Services
# 3                Information Technology
# 4                Information Technology
#
#                                     SectorType               RevenueType  \
# 0                                Manufacturing   $5 to $10 billion (USD)
# 1           Government & Public Administration  $25 to $50 million (USD)
# 2  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 3                     Unknown / Non-Applicable                        -2
# 4                     Unknown / Non-Applicable                        -2
#
#    Rating      SalaryExtract SalaryExtractHourly
# 0     4.1   US$74K - US$125K                 NaN
# 1     3.6                NaN                 NaN
# 2     4.0   US$90K - US$120K                 NaN
# 3    -2.0  US$105K - US$146K                 NaN
# 4    -2.0                NaN                 NaN

# %%
df.drop(columns=df.columns[0], axis=1, inplace=True)

# %%
df.head()
# Out:
#                          CompanyName       Location  \
# 0            NXP Semiconductors\n4.1     Austin, TX
# 1             State of Virginia\n3.6         Remote
# 2  Matrix New World Engineering\n4.0         Remote
# 3                       Context Labs  Cambridge, MA
# 4                            Unknown  Cambridge, MA
#
#                                            Job_Title  \
# 0  Entry Level Data Science - December 2023 and M...
# 1                                     Data Scientist
# 2                                     Data Scientist
# 3                                     Data Scientist
# 4                                     Data Scientist
#
#                                       SalaryEstimate  \
# 0  NXP Semiconductors4.1 ★\nEntry Level Data Scie...
# 1  State of Virginia3.6 ★\nData Scientist\nRemote...
# 2  Matrix New World Engineering4 ★\nData Scientis...
# 3  Context Labs\nData Scientist\nCambridge, MA\nU...
# 4  CORMAC3.8 ★\nJr. Data Scientist\nRemote\nEasy ...
#
#                                             Job_Desc    NumberOfEmployees  \
# 0  Our business runs on Data, and having an accur...     10000+ Employees
# 1  Job Duties/Responsibilities may include, but a...     10000+ Employees
# 2  Are you passionate about finding insights from...  51 to 200 Employees
# 3  Context Labs is seeking a Data Scientist to su...              Unknown
# 4  Context Labs is seeking a Data Scientist to su...              Unknown
#
#        FoundingYear           CompanyType  \
# 0              2006      Company - Public
# 1              1788            Government
# 2              1990     Company - Private
# 3  Company - Public  Software Development
# 4  Company - Public  Software Development
#
#                            IndustryType  \
# 0             Electronics Manufacturing
# 1                     Regional Agencies
# 2  Architectural & Engineering Services
# 3                Information Technology
# 4                Information Technology
#
#                                     SectorType               RevenueType  \
# 0                                Manufacturing   $5 to $10 billion (USD)
# 1           Government & Public Administration  $25 to $50 million (USD)
# 2  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 3                     Unknown / Non-Applicable                        -2
# 4                     Unknown / Non-Applicable                        -2
#
#    Rating      SalaryExtract SalaryExtractHourly
# 0     4.1   US$74K - US$125K                 NaN
# 1     3.6                NaN                 NaN
# 2     4.0   US$90K - US$120K                 NaN
# 3    -2.0  US$105K - US$146K                 NaN
# 4    -2.0                NaN                 NaN

# %%
df.SalaryExtract=df.SalaryExtract.str.replace('K','',regex=True)

# %%
df.SalaryExtract=df.SalaryExtract.str.replace('US','',regex=True)

# %%
df.SalaryExtract=df.SalaryExtract.str.replace('$','',regex=True)

# %%
df.SalaryExtract
# Out:
# 0           $74 - $125
# 1                  NaN
# 2           $90 - $120
# 3          $105 - $146
# 4                  NaN
#             ...
# 894        $112 - $225
# 895         $80 - $120
# 896         $90 - $140
# 897    $53.62 - $64.58
# 898                NaN
# Name: SalaryExtract, Length: 899, dtype: object

# %%
 df['SalaryExtract'].str.contains('$').any()
# Out:
# True

# %%
df['SalaryExtract'] = df['SalaryExtract'].str.replace('$', '')

# %%
df['SalaryExtract']
# Out:
# 0           74 - 125
# 1                NaN
# 2           90 - 120
# 3          105 - 146
# 4                NaN
#            ...
# 894        112 - 225
# 895         80 - 120
# 896         90 - 140
# 897    53.62 - 64.58
# 898              NaN
# Name: SalaryExtract, Length: 899, dtype: object

# %%
df['SalaryExtract'].dropna(inplace=True)

# %%
df['SalaryExtract'].value_counts().sum()
# Out:
# 659

# %%
df['SalaryExtract'].value_counts()
# Out:
# SalaryExtract
# 74 - 125         30
# 90 - 120         30
# 53.62 - 64.58    30
# 90 - 140         30
# 80 - 120         30
# 112 - 225        30
# 70 - 105         30
# 100 - 120        30
# 71 - 133         30
# 50.00 - 55.00    30
# 132              30
# 93 - 132         30
# 48 - 78          30
# 80 - 110         30
# 92 - 143         30
# 112 - 135        30
# 102 - 144        30
# 60 - 140         30
# 83 - 114         30
# 60.00 - 70.00    30
# 105 - 146        30
# 90 - 133         29
# Name: count, dtype: int64

# %%
def undersplit(x):
    x = str(x)
    if "-" in x:
        return x.split("-", 1)
    else:
        return [x, 0]

# %%
df[["minSalary","maxSalary"]] = [ undersplit(i) for i in df['SalaryExtract']]

# %%
df['SalaryExtract']
# Out:
# 0           74 - 125
# 1                NaN
# 2           90 - 120
# 3          105 - 146
# 4                NaN
#            ...
# 894        112 - 225
# 895         80 - 120
# 896         90 - 140
# 897    53.62 - 64.58
# 898              NaN
# Name: SalaryExtract, Length: 899, dtype: object

# %%
df[["minSalary","maxSalary"]].head(10)
#.str.split(r'\.', 1, expand=True
# Out:
#   minSalary maxSalary
# 0       74        125
# 1       nan         0
# 2       90        120
# 3      105        146
# 4       nan         0
# 5    60.00      70.00
# 6       nan         0
# 7       nan         0
# 8       83        114
# 9       60        140

# %%
df.columns
# Out:
# Index(['CompanyName', 'Location', 'Job_Title', 'SalaryEstimate', 'Job_Desc',
#        'NumberOfEmployees', 'FoundingYear', 'CompanyType', 'IndustryType',
#        'SectorType', 'RevenueType', 'Rating', 'SalaryExtract',
#        'SalaryExtractHourly', 'minSalary', 'maxSalary'],
#       dtype='object')

# %%
df.drop(["SalaryExtract"],inplace=True, axis=1)

# %%
df.columns
# Out:
# Index(['CompanyName', 'Location', 'Job_Title', 'SalaryEstimate', 'Job_Desc',
#        'NumberOfEmployees', 'FoundingYear', 'CompanyType', 'IndustryType',
#        'SectorType', 'RevenueType', 'Rating', 'SalaryExtractHourly',
#        'minSalary', 'maxSalary'],
#       dtype='object')

# %%
df.drop(['SalaryExtractHourly'], axis=1,inplace = True)

# %%
df.columns
# Out:
# Index(['CompanyName', 'Location', 'Job_Title', 'SalaryEstimate', 'Job_Desc',
#        'NumberOfEmployees', 'FoundingYear', 'CompanyType', 'IndustryType',
#        'SectorType', 'RevenueType', 'Rating', 'minSalary', 'maxSalary'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['CompanyName', 'Location', 'Job_Title', 'SalaryEstimate', 'Job_Desc',
#        'NumberOfEmployees', 'FoundingYear', 'CompanyType', 'IndustryType',
#        'SectorType', 'RevenueType', 'Rating', 'minSalary', 'maxSalary'],
#       dtype='object')

# %%
#df.dropna(subset=['minSalary'], inplace=True)

# %%
df.shape
# Out:
# (899, 14)

# %%
dfresult = df.dropna()

# %%
df.dropna(inplace= True)

# %%
df
# Out:
#                            CompanyName       Location  \
# 0              NXP Semiconductors\n4.1     Austin, TX
# 1               State of Virginia\n3.6         Remote
# 2    Matrix New World Engineering\n4.0         Remote
# 3                         Context Labs  Cambridge, MA
# 4                              Unknown  Cambridge, MA
# ..                                 ...            ...
# 894                           Tidepool  Palo Alto, CA
# 895        FAST GROWING TREES LLC\n4.2         Remote
# 896                            Unknown         Remote
# 897                          Nexlogica         Remote
# 898                            Unknown         Remote
#
#                                              Job_Title  \
# 0    Entry Level Data Science - December 2023 and M...
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 894                 Data Scientist (Remote - US based)
# 895                                     Data Scientist
# 896                                     Data Scientist
# 897                                     Data Scientist
# 898                                     Data Scientist
#
#                                         SalaryEstimate  \
# 0    NXP Semiconductors4.1 ★\nEntry Level Data Scie...
# 1    State of Virginia3.6 ★\nData Scientist\nRemote...
# 2    Matrix New World Engineering4 ★\nData Scientis...
# 3    Context Labs\nData Scientist\nCambridge, MA\nU...
# 4    CORMAC3.8 ★\nJr. Data Scientist\nRemote\nEasy ...
# ..                                                 ...
# 894  Tidepool\nData Scientist (Remote - US based)\n...
# 895  FAST GROWING TREES LLC4.2 ★\nData Scientist\nR...
# 896  HawkEye3603.4 ★\nJunior Data Scientist\nHerndo...
# 897  Nexlogica\nData Scientist\nRemote\nUS$53.62 - ...
# 898  Buyers Edge Platform, LLC4.3 ★\nData Scientist...
#
#                                               Job_Desc    NumberOfEmployees  \
# 0    Our business runs on Data, and having an accur...     10000+ Employees
# 1    Job Duties/Responsibilities may include, but a...     10000+ Employees
# 2    Are you passionate about finding insights from...  51 to 200 Employees
# 3    Context Labs is seeking a Data Scientist to su...              Unknown
# 4    Context Labs is seeking a Data Scientist to su...              Unknown
# ..                                                 ...                  ...
# 894  Company Description\n\nDue to the nature of th...    1 to 50 Employees
# 895  Description:\n\nAbout the Company\nFast Growin...  51 to 200 Employees
# 896  Description:\n\nAbout the Company\nFast Growin...  51 to 200 Employees
# 897  Skills :\nPossess knowledge and technical expe...  51 to 200 Employees
# 898  Skills :\nPossess knowledge and technical expe...  51 to 200 Employees
#
#          FoundingYear               CompanyType  \
# 0                2006          Company - Public
# 1                1788                Government
# 2                1990         Company - Private
# 3    Company - Public      Software Development
# 4    Company - Public      Software Development
# ..                ...                       ...
# 894              2013   Non-profit Organisation
# 895              2005         Company - Private
# 896              2005         Company - Private
# 897  Company - Public  Unknown / Non-Applicable
# 898  Company - Public  Unknown / Non-Applicable
#
#                              IndustryType  \
# 0               Electronics Manufacturing
# 1                       Regional Agencies
# 2    Architectural & Engineering Services
# 3                  Information Technology
# 4                  Information Technology
# ..                                    ...
# 894       Healthcare Services & Hospitals
# 895    Home Furniture & Housewares Stores
# 896    Home Furniture & Housewares Stores
# 897                               Unknown
# 898                               Unknown
#
#                                       SectorType               RevenueType  \
# 0                                  Manufacturing   $5 to $10 billion (USD)
# 1             Government & Public Administration  $25 to $50 million (USD)
# 2    Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 3                       Unknown / Non-Applicable                        -2
# 4                       Unknown / Non-Applicable                        -2
# ..                                           ...                       ...
# 894                                   Healthcare   $5 to $25 million (USD)
# 895                           Retail & Wholesale  Unknown / Non-Applicable
# 896                           Retail & Wholesale  Unknown / Non-Applicable
# 897                                      Unknown                        -2
# 898                                      Unknown                        -2
#
#      Rating minSalary maxSalary
# 0       4.1       74        125
# 1       3.6       nan         0
# 2       4.0       90        120
# 3      -2.0      105        146
# 4      -2.0       nan         0
# ..      ...       ...       ...
# 894     4.4      112        225
# 895     4.2       80        120
# 896     4.2       90        140
# 897    -2.0    53.62      64.58
# 898    -2.0       nan         0
#
# [899 rows x 14 columns]

# %%
df.isna().sum()
# Out:
# CompanyName          0
# Location             0
# Job_Title            0
# SalaryEstimate       0
# Job_Desc             0
# NumberOfEmployees    0
# FoundingYear         0
# CompanyType          0
# IndustryType         0
# SectorType           0
# RevenueType          0
# Rating               0
# minSalary            0
# maxSalary            0
# dtype: int64

# %%
df = df.drop(df[df['minSalary'] == 'nan'].index)

# %%
df
# Out:
#                            CompanyName       Location  \
# 0              NXP Semiconductors\n4.1     Austin, TX
# 2    Matrix New World Engineering\n4.0         Remote
# 3                         Context Labs  Cambridge, MA
# 5                     Ryden Global LLC         Remote
# 8      Buchanan And Edwards Group\n4.0     McLean, VA
# ..                                 ...            ...
# 893                Publicis Media\n3.9   New York, NY
# 894                           Tidepool  Palo Alto, CA
# 895        FAST GROWING TREES LLC\n4.2         Remote
# 896                            Unknown         Remote
# 897                          Nexlogica         Remote
#
#                                              Job_Title  \
# 0    Entry Level Data Science - December 2023 and M...
# 2                                       Data Scientist
# 3                                       Data Scientist
# 5                                       Data Scientist
# 8                                       Data Scientist
# ..                                                 ...
# 893                              Junior Data Scientist
# 894                 Data Scientist (Remote - US based)
# 895                                     Data Scientist
# 896                                     Data Scientist
# 897                                     Data Scientist
#
#                                         SalaryEstimate  \
# 0    NXP Semiconductors4.1 ★\nEntry Level Data Scie...
# 2    Matrix New World Engineering4 ★\nData Scientis...
# 3    Context Labs\nData Scientist\nCambridge, MA\nU...
# 5    Ryden Global LLC\nData Scientist\nRemote\nUS$6...
# 8    Buchanan And Edwards Group4 ★\nData Scientist\...
# ..                                                 ...
# 893  Publicis Media3.9 ★\nJunior Data Scientist\nNe...
# 894  Tidepool\nData Scientist (Remote - US based)\n...
# 895  FAST GROWING TREES LLC4.2 ★\nData Scientist\nR...
# 896  HawkEye3603.4 ★\nJunior Data Scientist\nHerndo...
# 897  Nexlogica\nData Scientist\nRemote\nUS$53.62 - ...
#
#                                               Job_Desc     NumberOfEmployees  \
# 0    Our business runs on Data, and having an accur...      10000+ Employees
# 2    Are you passionate about finding insights from...   51 to 200 Employees
# 3    Context Labs is seeking a Data Scientist to su...               Unknown
# 5    We are looking for a data scientist that will ...                    -2
# 8    The Sponsor provides data-driven business anal...  201 to 500 Employees
# ..                                                 ...                   ...
# 893  Company Description\n\nRead this first: If you...      10000+ Employees
# 894  Company Description\n\nDue to the nature of th...     1 to 50 Employees
# 895  Description:\n\nAbout the Company\nFast Growin...   51 to 200 Employees
# 896  Description:\n\nAbout the Company\nFast Growin...   51 to 200 Employees
# 897  Skills :\nPossess knowledge and technical expe...   51 to 200 Employees
#
#          FoundingYear               CompanyType  \
# 0                2006          Company - Public
# 2                1990         Company - Private
# 3    Company - Public      Software Development
# 5                   0                   Unknown
# 8                1998         Company - Private
# ..                ...                       ...
# 893              1926          Company - Public
# 894              2013   Non-profit Organisation
# 895              2005         Company - Private
# 896              2005         Company - Private
# 897  Company - Public  Unknown / Non-Applicable
#
#                                 IndustryType  \
# 0                  Electronics Manufacturing
# 2       Architectural & Engineering Services
# 3                     Information Technology
# 5                                    Unknown
# 8    Information Technology Support Services
# ..                                       ...
# 893           Advertising & Public Relations
# 894          Healthcare Services & Hospitals
# 895       Home Furniture & Housewares Stores
# 896       Home Furniture & Housewares Stores
# 897                                  Unknown
#
#                                       SectorType               RevenueType  \
# 0                                  Manufacturing   $5 to $10 billion (USD)
# 2    Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 3                       Unknown / Non-Applicable                        -2
# 5                                        Unknown                        -2
# 8                         Information Technology  $25 to $50 million (USD)
# ..                                           ...                       ...
# 893                        Media & Communication   $5 to $10 billion (USD)
# 894                                   Healthcare   $5 to $25 million (USD)
# 895                           Retail & Wholesale  Unknown / Non-Applicable
# 896                           Retail & Wholesale  Unknown / Non-Applicable
# 897                                      Unknown                        -2
#
#      Rating minSalary maxSalary
# 0       4.1       74        125
# 2       4.0       90        120
# 3      -2.0      105        146
# 5      -2.0    60.00      70.00
# 8       4.0       83        114
# ..      ...       ...       ...
# 893     3.9       70        105
# 894     4.4      112        225
# 895     4.2       80        120
# 896     4.2       90        140
# 897    -2.0    53.62      64.58
#
# [659 rows x 14 columns]

# %%
df.Job_Title.value_counts()
# Out:
# Job_Title
# Data Scientist                                                 508
# Sr. Data Analyst                                                60
# Data Scientist 4676                                             30
# Junior Data Scientist                                           30
# Data Scientist (Remote - US based)                              30
# Entry Level Data Science - December 2023 and May 2024 Grads      1
# Name: count, dtype: int64

# %%
df.CompanyName.value_counts()
# Out:
# CompanyName
# Unknown                              209
# Nexlogica                             30
# Context Labs                          30
# Ryden Global LLC                      30
# Buchanan And Edwards Group\n4.0       30
# Tech brothers infoservices            30
# MetroStar\n3.5                        30
# Brainwave360                          30
# Matrix New World Engineering\n4.0     30
# Lendistry\n3.6                        30
# Sunixa Solutions\n4.9                 30
# plaxonic\n4.4                         30
# Publicis Media\n3.9                   30
# Tidepool                              30
# FAST GROWING TREES LLC\n4.2           30
# SilverEdge                            29
# NXP Semiconductors\n4.1                1
# Name: count, dtype: int64

# %%
df[df.CompanyName=="Matrix New World Engineering\n4.0"]
# Out:
#                            CompanyName Location       Job_Title  \
# 2    Matrix New World Engineering\n4.0   Remote  Data Scientist
# 32   Matrix New World Engineering\n4.0   Remote  Data Scientist
# 62   Matrix New World Engineering\n4.0   Remote  Data Scientist
# 92   Matrix New World Engineering\n4.0   Remote  Data Scientist
# 122  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 152  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 182  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 212  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 242  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 272  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 302  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 332  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 362  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 392  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 422  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 452  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 482  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 512  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 542  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 572  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 602  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 632  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 662  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 692  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 722  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 752  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 782  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 812  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 842  Matrix New World Engineering\n4.0   Remote  Data Scientist
# 872  Matrix New World Engineering\n4.0   Remote  Data Scientist
#
#                                         SalaryEstimate  \
# 2    Matrix New World Engineering4 ★\nData Scientis...
# 32   Matrix New World Engineering4 ★\nData Scientis...
# 62   Matrix New World Engineering4 ★\nData Scientis...
# 92   Matrix New World Engineering4 ★\nData Scientis...
# 122  Matrix New World Engineering4 ★\nData Scientis...
# 152  Matrix New World Engineering4 ★\nData Scientis...
# 182  Matrix New World Engineering4 ★\nData Scientis...
# 212  Matrix New World Engineering4 ★\nData Scientis...
# 242  Matrix New World Engineering4 ★\nData Scientis...
# 272  Matrix New World Engineering4 ★\nData Scientis...
# 302  Matrix New World Engineering4 ★\nData Scientis...
# 332  Matrix New World Engineering4 ★\nData Scientis...
# 362  Matrix New World Engineering4 ★\nData Scientis...
# 392  Matrix New World Engineering4 ★\nData Scientis...
# 422  Matrix New World Engineering4 ★\nData Scientis...
# 452  Matrix New World Engineering4 ★\nData Scientis...
# 482  Matrix New World Engineering4 ★\nData Scientis...
# 512  Matrix New World Engineering4 ★\nData Scientis...
# 542  Matrix New World Engineering4 ★\nData Scientis...
# 572  Matrix New World Engineering4 ★\nData Scientis...
# 602  Matrix New World Engineering4 ★\nData Scientis...
# 632  Matrix New World Engineering4 ★\nData Scientis...
# 662  Matrix New World Engineering4 ★\nData Scientis...
# 692  Matrix New World Engineering4 ★\nData Scientis...
# 722  Matrix New World Engineering4 ★\nData Scientis...
# 752  Matrix New World Engineering4 ★\nData Scientis...
# 782  Matrix New World Engineering4 ★\nData Scientis...
# 812  Matrix New World Engineering4 ★\nData Scientis...
# 842  Matrix New World Engineering4 ★\nData Scientis...
# 872  Matrix New World Engineering4 ★\nData Scientis...
#
#                                               Job_Desc    NumberOfEmployees  \
# 2    Are you passionate about finding insights from...  51 to 200 Employees
# 32   Are you passionate about finding insights from...  51 to 200 Employees
# 62   Are you passionate about finding insights from...  51 to 200 Employees
# 92   Are you passionate about finding insights from...  51 to 200 Employees
# 122  Are you passionate about finding insights from...  51 to 200 Employees
# 152  Are you passionate about finding insights from...  51 to 200 Employees
# 182  Are you passionate about finding insights from...  51 to 200 Employees
# 212  Are you passionate about finding insights from...  51 to 200 Employees
# 242  Are you passionate about finding insights from...  51 to 200 Employees
# 272  Are you passionate about finding insights from...  51 to 200 Employees
# 302  Are you passionate about finding insights from...  51 to 200 Employees
# 332  Are you passionate about finding insights from...  51 to 200 Employees
# 362  Are you passionate about finding insights from...  51 to 200 Employees
# 392  Are you passionate about finding insights from...  51 to 200 Employees
# 422  Are you passionate about finding insights from...  51 to 200 Employees
# 452  Are you passionate about finding insights from...  51 to 200 Employees
# 482  Are you passionate about finding insights from...  51 to 200 Employees
# 512  Are you passionate about finding insights from...  51 to 200 Employees
# 542  Are you passionate about finding insights from...  51 to 200 Employees
# 572  Are you passionate about finding insights from...  51 to 200 Employees
# 602  Are you passionate about finding insights from...  51 to 200 Employees
# 632  Are you passionate about finding insights from...  51 to 200 Employees
# 662  Are you passionate about finding insights from...  51 to 200 Employees
# 692  Are you passionate about finding insights from...  51 to 200 Employees
# 722  Are you passionate about finding insights from...  51 to 200 Employees
# 752  Are you passionate about finding insights from...  51 to 200 Employees
# 782  Are you passionate about finding insights from...  51 to 200 Employees
# 812  Are you passionate about finding insights from...  51 to 200 Employees
# 842  Are you passionate about finding insights from...  51 to 200 Employees
# 872  Are you passionate about finding insights from...  51 to 200 Employees
#
#     FoundingYear        CompanyType                          IndustryType  \
# 2           1990  Company - Private  Architectural & Engineering Services
# 32          1990  Company - Private  Architectural & Engineering Services
# 62          1990  Company - Private  Architectural & Engineering Services
# 92          1990  Company - Private  Architectural & Engineering Services
# 122         1990  Company - Private  Architectural & Engineering Services
# 152         1990  Company - Private  Architectural & Engineering Services
# 182         1990  Company - Private  Architectural & Engineering Services
# 212         1990  Company - Private  Architectural & Engineering Services
# 242         1990  Company - Private  Architectural & Engineering Services
# 272         1990  Company - Private  Architectural & Engineering Services
# 302         1990  Company - Private  Architectural & Engineering Services
# 332         1990  Company - Private  Architectural & Engineering Services
# 362         1990  Company - Private  Architectural & Engineering Services
# 392         1990  Company - Private  Architectural & Engineering Services
# 422         1990  Company - Private  Architectural & Engineering Services
# 452         1990  Company - Private  Architectural & Engineering Services
# 482         1990  Company - Private  Architectural & Engineering Services
# 512         1990  Company - Private  Architectural & Engineering Services
# 542         1990  Company - Private  Architectural & Engineering Services
# 572         1990  Company - Private  Architectural & Engineering Services
# 602         1990  Company - Private  Architectural & Engineering Services
# 632         1990  Company - Private  Architectural & Engineering Services
# 662         1990  Company - Private  Architectural & Engineering Services
# 692         1990  Company - Private  Architectural & Engineering Services
# 722         1990  Company - Private  Architectural & Engineering Services
# 752         1990  Company - Private  Architectural & Engineering Services
# 782         1990  Company - Private  Architectural & Engineering Services
# 812         1990  Company - Private  Architectural & Engineering Services
# 842         1990  Company - Private  Architectural & Engineering Services
# 872         1990  Company - Private  Architectural & Engineering Services
#
#                                       SectorType               RevenueType  \
# 2    Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 32   Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 62   Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 92   Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 122  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 152  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 182  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 212  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 242  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 272  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 302  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 332  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 362  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 392  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 422  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 452  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 482  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 512  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 542  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 572  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 602  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 632  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 662  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 692  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 722  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 752  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 782  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 812  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 842  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 872  Construction, Repair & Maintenance Services  $25 to $50 million (USD)
#
#      Rating minSalary maxSalary
# 2       4.0       90        120
# 32      4.0       90        120
# 62      4.0       90        120
# 92      4.0       90        120
# 122     4.0       90        120
# 152     4.0       90        120
# 182     4.0       90        120
# 212     4.0       90        120
# 242     4.0       90        120
# 272     4.0       90        120
# 302     4.0       90        120
# 332     4.0       90        120
# 362     4.0       90        120
# 392     4.0       90        120
# 422     4.0       90        120
# 452     4.0       90        120
# 482     4.0       90        120
# 512     4.0       90        120
# 542     4.0       90        120
# 572     4.0       90        120
# 602     4.0       90        120
# 632     4.0       90        120
# 662     4.0       90        120
# 692     4.0       90        120
# 722     4.0       90        120
# 752     4.0       90        120
# 782     4.0       90        120
# 812     4.0       90        120
# 842     4.0       90        120
# 872     4.0       90        120

# %%
df["HourlyminSal"] = df.minSalary.str.extract(r'([0-9]+[0-9]\.+[0-9]+[0-9])')

# %%
df["HourlyminSal"]
# Out:
# 0        NaN
# 2        NaN
# 3        NaN
# 5      60.00
# 8        NaN
#        ...
# 893      NaN
# 894      NaN
# 895      NaN
# 896      NaN
# 897    53.62
# Name: HourlyminSal, Length: 659, dtype: object

# %%
df.HourlyminSal = df.HourlyminSal.astype(float)

# %%
df.HourlyminSal.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 659 entries, 0 to 897
# Series name: HourlyminSal
# Non-Null Count  Dtype
# --------------  -----
# 90 non-null     float64
# dtypes: float64(1)
# memory usage: 10.3 KB

# %%
#df['Hourly'] = df['Hourly']*10

# %%
def mutiply(x):
    if x=="NaN":
        x="NaN"
        return x
    else:
        b = x*8
        x = ((b*22)*12)/1000
        return x

# %%
df.HourlyminSal =  [ mutiply(i) for i in df['HourlyminSal']]

# %%
df['HourlyminSal'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 659 entries, 0 to 897
# Series name: HourlyminSal
# Non-Null Count  Dtype
# --------------  -----
# 90 non-null     float64
# dtypes: float64(1)
# memory usage: 10.3 KB

# %%
df
# Out:
#                            CompanyName       Location  \
# 0              NXP Semiconductors\n4.1     Austin, TX
# 2    Matrix New World Engineering\n4.0         Remote
# 3                         Context Labs  Cambridge, MA
# 5                     Ryden Global LLC         Remote
# 8      Buchanan And Edwards Group\n4.0     McLean, VA
# ..                                 ...            ...
# 893                Publicis Media\n3.9   New York, NY
# 894                           Tidepool  Palo Alto, CA
# 895        FAST GROWING TREES LLC\n4.2         Remote
# 896                            Unknown         Remote
# 897                          Nexlogica         Remote
#
#                                              Job_Title  \
# 0    Entry Level Data Science - December 2023 and M...
# 2                                       Data Scientist
# 3                                       Data Scientist
# 5                                       Data Scientist
# 8                                       Data Scientist
# ..                                                 ...
# 893                              Junior Data Scientist
# 894                 Data Scientist (Remote - US based)
# 895                                     Data Scientist
# 896                                     Data Scientist
# 897                                     Data Scientist
#
#                                         SalaryEstimate  \
# 0    NXP Semiconductors4.1 ★\nEntry Level Data Scie...
# 2    Matrix New World Engineering4 ★\nData Scientis...
# 3    Context Labs\nData Scientist\nCambridge, MA\nU...
# 5    Ryden Global LLC\nData Scientist\nRemote\nUS$6...
# 8    Buchanan And Edwards Group4 ★\nData Scientist\...
# ..                                                 ...
# 893  Publicis Media3.9 ★\nJunior Data Scientist\nNe...
# 894  Tidepool\nData Scientist (Remote - US based)\n...
# 895  FAST GROWING TREES LLC4.2 ★\nData Scientist\nR...
# 896  HawkEye3603.4 ★\nJunior Data Scientist\nHerndo...
# 897  Nexlogica\nData Scientist\nRemote\nUS$53.62 - ...
#
#                                               Job_Desc     NumberOfEmployees  \
# 0    Our business runs on Data, and having an accur...      10000+ Employees
# 2    Are you passionate about finding insights from...   51 to 200 Employees
# 3    Context Labs is seeking a Data Scientist to su...               Unknown
# 5    We are looking for a data scientist that will ...                    -2
# 8    The Sponsor provides data-driven business anal...  201 to 500 Employees
# ..                                                 ...                   ...
# 893  Company Description\n\nRead this first: If you...      10000+ Employees
# 894  Company Description\n\nDue to the nature of th...     1 to 50 Employees
# 895  Description:\n\nAbout the Company\nFast Growin...   51 to 200 Employees
# 896  Description:\n\nAbout the Company\nFast Growin...   51 to 200 Employees
# 897  Skills :\nPossess knowledge and technical expe...   51 to 200 Employees
#
#          FoundingYear               CompanyType  \
# 0                2006          Company - Public
# 2                1990         Company - Private
# 3    Company - Public      Software Development
# 5                   0                   Unknown
# 8                1998         Company - Private
# ..                ...                       ...
# 893              1926          Company - Public
# 894              2013   Non-profit Organisation
# 895              2005         Company - Private
# 896              2005         Company - Private
# 897  Company - Public  Unknown / Non-Applicable
#
#                                 IndustryType  \
# 0                  Electronics Manufacturing
# 2       Architectural & Engineering Services
# 3                     Information Technology
# 5                                    Unknown
# 8    Information Technology Support Services
# ..                                       ...
# 893           Advertising & Public Relations
# 894          Healthcare Services & Hospitals
# 895       Home Furniture & Housewares Stores
# 896       Home Furniture & Housewares Stores
# 897                                  Unknown
#
#                                       SectorType               RevenueType  \
# 0                                  Manufacturing   $5 to $10 billion (USD)
# 2    Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 3                       Unknown / Non-Applicable                        -2
# 5                                        Unknown                        -2
# 8                         Information Technology  $25 to $50 million (USD)
# ..                                           ...                       ...
# 893                        Media & Communication   $5 to $10 billion (USD)
# 894                                   Healthcare   $5 to $25 million (USD)
# 895                           Retail & Wholesale  Unknown / Non-Applicable
# 896                           Retail & Wholesale  Unknown / Non-Applicable
# 897                                      Unknown                        -2
#
#      Rating minSalary maxSalary  HourlyminSal
# 0       4.1       74        125           NaN
# 2       4.0       90        120           NaN
# 3      -2.0      105        146           NaN
# 5      -2.0    60.00      70.00     126.72000
# 8       4.0       83        114           NaN
# ..      ...       ...       ...           ...
# 893     3.9       70        105           NaN
# 894     4.4      112        225           NaN
# 895     4.2       80        120           NaN
# 896     4.2       90        140           NaN
# 897    -2.0    53.62      64.58     113.24544
#
# [659 rows x 15 columns]

# %%
for i, j in zip(df['minSalary'].head(5),df['HourlyminSal'].head(5)):
    print(j,i)
    if j=="NaN":
        print(j,i)
        #df["minSalary"] = i
        
    #else:
        #df["minSalary"] = j
# Out:
# nan 74
# nan 90
# nan 105
# 126.72 60.00
# nan 83

# %%
df
# Out:
#                            CompanyName       Location  \
# 0              NXP Semiconductors\n4.1     Austin, TX
# 2    Matrix New World Engineering\n4.0         Remote
# 3                         Context Labs  Cambridge, MA
# 5                     Ryden Global LLC         Remote
# 8      Buchanan And Edwards Group\n4.0     McLean, VA
# ..                                 ...            ...
# 893                Publicis Media\n3.9   New York, NY
# 894                           Tidepool  Palo Alto, CA
# 895        FAST GROWING TREES LLC\n4.2         Remote
# 896                            Unknown         Remote
# 897                          Nexlogica         Remote
#
#                                              Job_Title  \
# 0    Entry Level Data Science - December 2023 and M...
# 2                                       Data Scientist
# 3                                       Data Scientist
# 5                                       Data Scientist
# 8                                       Data Scientist
# ..                                                 ...
# 893                              Junior Data Scientist
# 894                 Data Scientist (Remote - US based)
# 895                                     Data Scientist
# 896                                     Data Scientist
# 897                                     Data Scientist
#
#                                         SalaryEstimate  \
# 0    NXP Semiconductors4.1 ★\nEntry Level Data Scie...
# 2    Matrix New World Engineering4 ★\nData Scientis...
# 3    Context Labs\nData Scientist\nCambridge, MA\nU...
# 5    Ryden Global LLC\nData Scientist\nRemote\nUS$6...
# 8    Buchanan And Edwards Group4 ★\nData Scientist\...
# ..                                                 ...
# 893  Publicis Media3.9 ★\nJunior Data Scientist\nNe...
# 894  Tidepool\nData Scientist (Remote - US based)\n...
# 895  FAST GROWING TREES LLC4.2 ★\nData Scientist\nR...
# 896  HawkEye3603.4 ★\nJunior Data Scientist\nHerndo...
# 897  Nexlogica\nData Scientist\nRemote\nUS$53.62 - ...
#
#                                               Job_Desc     NumberOfEmployees  \
# 0    Our business runs on Data, and having an accur...      10000+ Employees
# 2    Are you passionate about finding insights from...   51 to 200 Employees
# 3    Context Labs is seeking a Data Scientist to su...               Unknown
# 5    We are looking for a data scientist that will ...                    -2
# 8    The Sponsor provides data-driven business anal...  201 to 500 Employees
# ..                                                 ...                   ...
# 893  Company Description\n\nRead this first: If you...      10000+ Employees
# 894  Company Description\n\nDue to the nature of th...     1 to 50 Employees
# 895  Description:\n\nAbout the Company\nFast Growin...   51 to 200 Employees
# 896  Description:\n\nAbout the Company\nFast Growin...   51 to 200 Employees
# 897  Skills :\nPossess knowledge and technical expe...   51 to 200 Employees
#
#          FoundingYear               CompanyType  \
# 0                2006          Company - Public
# 2                1990         Company - Private
# 3    Company - Public      Software Development
# 5                   0                   Unknown
# 8                1998         Company - Private
# ..                ...                       ...
# 893              1926          Company - Public
# 894              2013   Non-profit Organisation
# 895              2005         Company - Private
# 896              2005         Company - Private
# 897  Company - Public  Unknown / Non-Applicable
#
#                                 IndustryType  \
# 0                  Electronics Manufacturing
# 2       Architectural & Engineering Services
# 3                     Information Technology
# 5                                    Unknown
# 8    Information Technology Support Services
# ..                                       ...
# 893           Advertising & Public Relations
# 894          Healthcare Services & Hospitals
# 895       Home Furniture & Housewares Stores
# 896       Home Furniture & Housewares Stores
# 897                                  Unknown
#
#                                       SectorType               RevenueType  \
# 0                                  Manufacturing   $5 to $10 billion (USD)
# 2    Construction, Repair & Maintenance Services  $25 to $50 million (USD)
# 3                       Unknown / Non-Applicable                        -2
# 5                                        Unknown                        -2
# 8                         Information Technology  $25 to $50 million (USD)
# ..                                           ...                       ...
# 893                        Media & Communication   $5 to $10 billion (USD)
# 894                                   Healthcare   $5 to $25 million (USD)
# 895                           Retail & Wholesale  Unknown / Non-Applicable
# 896                           Retail & Wholesale  Unknown / Non-Applicable
# 897                                      Unknown                        -2
#
#      Rating minSalary maxSalary  HourlyminSal
# 0       4.1       74        125           NaN
# 2       4.0       90        120           NaN
# 3      -2.0      105        146           NaN
# 5      -2.0    60.00      70.00     126.72000
# 8       4.0       83        114           NaN
# ..      ...       ...       ...           ...
# 893     3.9       70        105           NaN
# 894     4.4      112        225           NaN
# 895     4.2       80        120           NaN
# 896     4.2       90        140           NaN
# 897    -2.0    53.62      64.58     113.24544
#
# [659 rows x 15 columns]
